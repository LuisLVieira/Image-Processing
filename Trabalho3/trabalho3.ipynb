# %%
import glob
import os
from utils import get_fft_spectra, plot_spectra

# %% [markdown]
# ## Visualização das imagens

# %%
for image_path in glob.glob('images/*'):

    img, fft_mag, fft_mag_cent = get_fft_spectra(image_path)
    plot_spectra(
        img,
        fft_mag,
        fft_mag_cent,
        title = os.path.basename(image_path),
        output_path='./outputs'
)

# %%
for image_path in glob.glob('images/*'):

    _,_,fft_mag = get_fft_spectra(image_path)
    print(fft_mag.shape)
# Out:
# (512, 512)
# (512, 512)
# (512, 512)
# (480, 640)
# (512, 768)
# (594, 623)
# (512, 512)
# (256, 256)
# (510, 384)
# (768, 1024)
# (384, 507)
