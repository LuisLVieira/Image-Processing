# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import utils
import os
import glob

# %% [markdown]
# # Limiarização

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    images.append(image)
utils.plot_images(images, "Imagens Originais", fig_size=(10,10))

# %% [markdown]
# ## Método global

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.GlobaLimiarization(image)
    segmented_image = limiar_class.global_limiarization(T=128)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método Global (T=128)",
    save_dir='outputs/limiarização_global',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.GlobaLimiarization(image)
    segmented_image = limiar_class.global_limiarization(T=40)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método Global (T=40)",
    save_dir='outputs/limiarização_global',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.GlobaLimiarization(image)
    segmented_image = limiar_class.global_limiarization(T=170)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método Global (T=170)",
    save_dir='outputs/limiarização_global',
    fig_size=(10,10)
)

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.GlobaLimiarization(image)

    utils.plot_limarization(
        original_image = image,
        segmented_image = limiar_class.global_limiarization(T=128),
        title = f"Método Global {os.path.basename(image_path).split('.')[0]} T=128",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_global',
        threshold = 128
    )

# %%
image_path = "images/retina.pgm"
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
limiar_class = utils.GlobaLimiarization(image)

utils.plot_limarization(
    original_image = image,
    segmented_image = limiar_class.global_limiarization(T=40),
    title = f"Método Global {os.path.basename(image_path).split('.')[0]} T=30",
    figsize = (8, 8),
    save_dir = 'outputs/limiarização_global',
    threshold = 30
)

image_path = "images/baboon.pgm"
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
limiar_class = utils.GlobaLimiarization(image)

utils.plot_limarization(
    original_image = image,
    segmented_image = limiar_class.global_limiarization(T=170),
    title = f"Método Global {os.path.basename(image_path).split('.')[0]} T=160",
    figsize = (8, 8),
    save_dir = 'outputs/limiarização_global',
    threshold = 160
)

# %% [markdown]
# ## Método de Otsu

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.GlobaLimiarization(image)
    segmented_image, threshold = limiar_class.otsu_limiarization_cv()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Otsu Opencv",
    save_dir='outputs/limiarização_global_otsu',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.GlobaLimiarization(image)
    segmented_image, threshold = limiar_class.otsu_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Otsu",
    save_dir='outputs/limiarização_global_otsu',
    fig_size=(10,10)
)

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.GlobaLimiarization(image)
    segmented_image, threshold = limiar_class.otsu_limiarization()

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Otsu {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_global_otsu',
        threshold = threshold
    )

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.GlobaLimiarization(image)
    segmented_image, threshold = limiar_class.otsu_limiarization_cv()

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Otsu opencv {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_global_otsu',
        threshold = threshold
    )

# %% [markdown]
# ## Método de Bernsen

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=5)
    segmented_image= limiar_class.bernsen_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Bernsen window 5",
    save_dir='outputs/limiarização_local_bersen',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=21)
    segmented_image= limiar_class.bernsen_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Bernsen window 21",
    save_dir='outputs/limiarização_local_bersen',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=31)
    segmented_image= limiar_class.bernsen_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Bernsen window 31",
    save_dir='outputs/limiarização_local_bersen',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.bernsen_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Bernsen window 15",
    save_dir='outputs/limiarização_local_bersen',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=41)
    segmented_image= limiar_class.bernsen_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Bernsen window 41",
    save_dir='outputs/limiarização_local_bersen',
    fig_size=(10,10)
)

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image = limiar_class.bernsen_limiarization()

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Bersen window 15 {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_local_bersen'
    )

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=31)
    segmented_image = limiar_class.bernsen_limiarization()

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Bersen window 31 {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_local_bersen'
    )

# %% [markdown]
# ## Método de Niblack

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=31)
    segmented_image= limiar_class.niblack_limiarization(k=0.2)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Niblack window 31 k 0.2",
    save_dir='outputs/limiarização_local_niblack',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.niblack_limiarization(k=0.2)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Niblack window 15 k 0.2",
    save_dir='outputs/limiarização_local_niblack',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.niblack_limiarization(k=-0.2)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Niblack window 15 k -0.2",
    save_dir='outputs/limiarização_local_niblack',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.niblack_limiarization(k=0.7)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Niblack window 15 k 0.7",
    save_dir='outputs/limiarização_local_niblack',
    fig_size=(10,10)
)

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image = limiar_class.niblack_limiarization(k=-0.2)

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Niblack window 15 k -0.2 {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_local_niblack'
    )

# %% [markdown]
# ## Método de Sauvola e Pietaksinen

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.sauvola_limiarization(k=0.5, R=128)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Sauvola e Pietaksinen window 15 k 0.5 R 128",
    save_dir='outputs/limiarização_local_sauvola',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=31)
    segmented_image= limiar_class.sauvola_limiarization(k=0.5, R=128)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Sauvola e Pietaksinen window 31 k 0.5 R 128",
    save_dir='outputs/limiarização_local_sauvola',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.sauvola_limiarization(k=0.2, R=128)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Sauvola e Pietaksinen window 15 k 0.2 R 128",
    save_dir='outputs/limiarização_local_sauvola',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.sauvola_limiarization(k=0.5, R=50)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Sauvola e Pietaksinen window 15 k 0.5 R 50",
    save_dir='outputs/limiarização_local_sauvola',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.sauvola_limiarization(k=0.5, R=200)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Sauvola e Pietaksinen window 15 k 0.5 R 200",
    save_dir='outputs/limiarização_local_sauvola',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.sauvola_limiarization(k=0.15, R=128)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Sauvola e Pietaksinen window 15 k 0.15 R 128",
    save_dir='outputs/limiarização_local_sauvola',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=31)
    segmented_image= limiar_class.sauvola_limiarization(k=0.30, R=128)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Sauvola e Pietaksinen window 31 k 0.30 R 128",
    save_dir='outputs/limiarização_local_sauvola',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=31)
    segmented_image= limiar_class.sauvola_limiarization(k=0.25, R=128)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Sauvola e Pietaksinen window 31 k 0.25 R 128",
    save_dir='outputs/limiarização_local_sauvola',
    fig_size=(10,10)
)

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image = limiar_class.sauvola_limiarization(k=0.15, R=128)

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Sauvola e Pietaksinen window 15 k 0.15 R 128 {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_local_sauvola'
    )

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image = limiar_class.sauvola_limiarization(k=0.5, R=128)

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Sauvola e Pietaksinen window 15 k 0.5 R 128 {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_local_sauvola'
    )

# %% [markdown]
# ## Método de Phansalskar, More e Sabale

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.phansalskar_limiarization(
        k=0.25,
        R=0.5,
        p=2,
        q=10
    )
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Phansalskar window 15 k 0.25 R 0.5 p 2 q 10",
    save_dir='outputs/limiarização_local_phansalskar',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.phansalskar_limiarization(
        k=0.20,
        R=0.5,
        p=2,
        q=10
    )
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Phansalskar window 15 k 0.20 R 0.5 p 2 q 10",
    save_dir='outputs/limiarização_local_phansalskar',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.phansalskar_limiarization(
        k=0.3,
        R=0.5,
        p=2,
        q=10
    )
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Phansalskar window 15 k 0.3 R 0.5 p 2 q 10",
    save_dir='outputs/limiarização_local_phansalskar',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.phansalskar_limiarization(
        k=0.10,
        R=0.5,
        p=2,
        q=10
    )
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Phansalskar window 15 k 0.10 R 0.5 p 2 q 10",
    save_dir='outputs/limiarização_local_phansalskar',
    fig_size=(10,10)
)

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.phansalskar_limiarization(
        k=0.20,
        R=0.5,
        p=2,
        q=10
    )

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Phansalskar window 15 k 0.2 R 0.5 p 2 q 10 {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_local_phansalskar'
    )

# %% [markdown]
# ## Método de contraste

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.contrast_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Contraste window 15",
    save_dir='outputs/limiarização_local_contraste',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=21)
    segmented_image= limiar_class.contrast_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Contraste window 21",
    save_dir='outputs/limiarização_local_contraste',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=43)
    segmented_image= limiar_class.contrast_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Contraste window 43",
    save_dir='outputs/limiarização_local_contraste',
    fig_size=(10,10)
)

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image = limiar_class.contrast_limiarization()

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Contraste window 15 {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_local_contraste'
    )

# %% [markdown]
# ## Método da Média

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.mean_limiarization(C=10)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Média window 15 C 10",
    save_dir='outputs/limiarização_local_media',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.mean_limiarization(C=90)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Média window 15 C 90",
    save_dir='outputs/limiarização_local_media',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.mean_limiarization(C=20)
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Média window 15 C 20",
    save_dir='outputs/limiarização_local_media',
    fig_size=(10,10)
)

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image = limiar_class.mean_limiarization(C=10)

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Média window 15 C 10 {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_local_media'
    )

# %% [markdown]
# ## Método da Mediana

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image= limiar_class.median_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Mediana window 15",
    save_dir='outputs/limiarização_local_mediana',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=43)
    segmented_image= limiar_class.median_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Mediana window 43",
    save_dir='outputs/limiarização_local_mediana',
    fig_size=(10,10)
)

# %%
images = []
for image_path in glob.glob('images/*'):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=11)
    segmented_image= limiar_class.median_limiarization()
    images.append(segmented_image)
utils.plot_images(
    images,
    "Método de Mediana window 11",
    save_dir='outputs/limiarização_local_mediana',
    fig_size=(10,10)
)

# %%
for image_path in glob.glob('images/*'):

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    limiar_class = utils.LocalLimiarization(image, window_size=15)
    segmented_image = limiar_class.median_limiarization()

    utils.plot_limarization(
        original_image = image,
        segmented_image = segmented_image,
        title = f"Método de Mediana window 15 {os.path.basename(image_path).split('.')[0]}",
        figsize = (8, 8),
        save_dir = 'outputs/limiarização_local_mediana'
    )
